# %%
# This Jupyter notebook connects to Kaggle and downloads the dataset that I will be using throughout this analysis

# %%
import kaggle

# %%
kaggle.api.authenticate()

# %%
kaggle.api.dataset_download_files("jehanzaibbhatti/sales-data", path=".", unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jehanzaibbhatti/sales-data
